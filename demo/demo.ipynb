# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def mapa(r,x):
  return r*x*(1-x)

# %%
r = 3.8

lista = []

for i in range(100):
  x = i/100
  m1= mapa(r,x)
  m2= mapa(r,m1)
  lista.append([x,m1,m2])

plt.plot(lista)
plt.show()
